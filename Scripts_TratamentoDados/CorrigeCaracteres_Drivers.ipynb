# %%
import pandas as pd
import magic 
import re

# %%
magic.from_file('drivers.csv')
# Out:
# 'Non-ISO extended-ASCII text, with CRLF line terminators'

# %%
df = pd.read_csv('drivers.csv',encoding= 'ISO-8859-1')
df.iloc[0:40]
# Out:
#     driverId           driverRef  number code    forename        surname  \
# 0          1            hamilton    44.0  HAM       Lewis       Hamilton
# 1          2            heidfeld     NaN  HEI        Nick       Heidfeld
# 2          3             rosberg     6.0  ROS        Nico        Rosberg
# 3          4              alonso    14.0  ALO    Fernando         Alonso
# 4          5          kovalainen     NaN  KOV      Heikki     Kovalainen
# 5          6            nakajima     NaN  NAK      Kazuki       Nakajima
# 6          7            bourdais     NaN  BOU  SÌ©bastien       Bourdais
# 7          8           raikkonen     7.0  RAI        Kimi    RÌ_ikkÌ¦nen
# 8          9              kubica     NaN  KUB      Robert         Kubica
# 9         10               glock     NaN  GLO        Timo          Glock
# 10        11                sato     NaN  SAT      Takuma           Sato
# 11        12           piquet_jr     NaN  PIQ      Nelson     Piquet Jr.
# ...

# %%
df.iloc[7]['url']
# Out:
# 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen'

# %%
for nome, _  in df.iteritems():
        if nome != 'url':
                df[nome].replace(['Ì_','Ì©','Ì£','Ì¦'], ['ä','é','ã','ö'],regex = True , inplace = True)
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_13400\3036298226.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for nome, _  in df.iteritems():
# driverId                                                       8
# driverRef                                              raikkonen
# number                                                       7.0
# code                                                         RAI
# forename                                                    Kimi
# surname                                                Räikkönen
# dob                                                   17/10/1979
# nationality                                              Finnish
# url            http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C...
# Name: 7, dtype: object

# %%
df.to_csv('drivers_v1.csv',encoding= 'ISO-8859-1',index=False)
